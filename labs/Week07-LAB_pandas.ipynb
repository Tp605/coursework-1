# %% [markdown]
# > # CST1510 Programming for data communication and networks
# > ## Week 7: Introduction to Pandas
# > ## LAB ACTIVITY
#
# ---
#
# ## Dataset
#
# All tasks use the file **`week07_data/students.csv`** (and `students_missing.csv` where stated).
#
# The dataset contains records of 25 university students:
#
# | Column | Type | Description |
# |--------|------|-------------|
# | `Name` | text | Student's full name |
# | `Age` | int | Student's age |
# | `Course` | text | Degree programme |
# | `Grade` | int | Module grade (0–100) |
# | `Attendance` | int | Attendance percentage (0–100) |
# | `City` | text | City of study |
# | `Scholarship` | text | `Yes` or `No` |
#
# ---
#
# ### Always start with this import cell:

# %%
import pandas as pd

df = pd.read_csv('week07_data/students.csv')
df.head()
# Out:
#             Name  Age            Course  Grade  Attendance        City  \
# 0  Alice Johnson   19  Computer Science     78          92      London
# 1      Bob Smith   21      Data Science     85          88  Manchester
# 2  Charlie Brown   20  Computer Science     62          75      London
# 3   Diana Prince   22       Mathematics     91          95  Birmingham
# 4     Eve Wilson   19      Data Science     73          80      London
#
#   Scholarship
# 0          No
# 1         Yes
# 2          No
# 3         Yes
# 4          No

# %% [markdown]
# ---
#
# # Easy (Threshold)
#
# > These tasks focus on **loading, exploring, and selecting** data using the basics covered in the workshop.

# %% [markdown]
# ---
#
# ### Task 1: Load and Explore
#
# Load `week07_data/students.csv` and print:
#
# 1. The **first 5 rows** of the dataset.
# 2. The **last 3 rows**.
# 3. The **number of rows and columns** (use `shape`).
# 4. The **column names** as a list.
#
# **Expected output (partial):**
# ```
# Shape: (25, 7)
# Columns: ['Name', 'Age', 'Course', 'Grade', 'Attendance', 'City', 'Scholarship']
# ```

# %%
# Task 1 — your code here
import pandas as pd

df= pd.read_csv('week07_data/students.csv')

print("First 5 rows:")
print(df.head())

# 2. Last 3 rows
print("\nLast 3 rows:")
print(df.tail(3))

# 3. Number of rows and columns
print("\nShape:", df.shape)

# 4. Column names as a list
print("Columns:", df.columns.tolist())
# Out:
# First 5 rows:
#             Name  Age            Course  Grade  Attendance        City  \
# 0  Alice Johnson   19  Computer Science     78          92      London
# 1      Bob Smith   21      Data Science     85          88  Manchester
# 2  Charlie Brown   20  Computer Science     62          75      London
# 3   Diana Prince   22       Mathematics     91          95  Birmingham
# 4     Eve Wilson   19      Data Science     73          80      London
#
#   Scholarship
# 0          No
# 1         Yes
# 2          No
# 3         Yes
# 4          No
#
# Last 3 rows:
#             Name  Age            Course  Grade  Attendance        City  \
# 22    Wendy King   19  Computer Science     88          92  Manchester
# 23  Xavier Scott   20       Mathematics     76          81      London
# 24    Yara Green   21      Data Science     93          96      London
#
#    Scholarship
# 22         Yes
# 23          No
# 24         Yes
#
# Shape: (25, 7)
# ...

# %% [markdown]
# ---
#
# ### Task 2: Data Types and Summary
#
# Using the loaded DataFrame:
#
# 1. Display the **data type** of each column.
# 2. Run `describe()` to get summary statistics.
# 3. Answer (as a `print` statement):
#    - What is the **average grade**?
#    - What is the **maximum attendance**?
#    - What is the **youngest student's age**?
#
# **Hint:** Use `df['column'].mean()`, `.max()`, `.min()`.

# %%
# Task 2 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# %% [markdown]
# ---
#
# ### Task 3: Selecting Columns and Rows
#
# 1. Create a new DataFrame called `grades_df` containing only the columns `Name`, `Course`, and `Grade`. Display the first 8 rows.
# 2. Use `iloc` to display rows **5 to 9** (positions).
# 3. Use `loc` to display the **Name** and **City** of the student at index `3`.
#
# **Hint:** For multiple columns, use `df[['col1', 'col2']]`.

# %%
# Task 3 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# %% [markdown]
# ---
#
# ### Task 4: Simple Filtering
#
# 1. Display all students who study in **London**. How many are there?
# 2. Display students whose **Grade is below 65**. Print their Name and Grade.
# 3. Use `value_counts()` on the `City` column to see how many students are in each city.
#
# **Expected output (partial):**
# ```
# Students in London: 11
# ```

# %%
# Task 4 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# %% [markdown]
# ---
#
# ### Task 5: Sort the Data
#
# 1. Sort the students by **Grade** from **highest to lowest** and display the top 5.
# 2. Sort by **City** (A → Z), and within each city, by **Grade** (lowest → highest).
#    Display the first 10 rows of the result.
#
# **Hint:** `sort_values(['col1', 'col2'], ascending=[True, False])`

# %%
# Task 5 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# %% [markdown]
# ---
#
# # Typical
#
# > These tasks require **combining multiple operations**: filtering with multiple conditions, adding columns, groupby analysis, and handling missing data.

# %% [markdown]
# ---
#
# ### Task 6: Grade Analysis with Multiple Conditions
#
# 1. Find all students who:
#    - Study **Computer Science** or **Data Science** (`isin()`), **AND**
#    - Have a **Grade above 75**, **AND**
#    - Have an **Attendance above 80**
#
#    Display their Name, Course, Grade, and Attendance.
#
# 2. How many students are at **risk of failing** (Grade < 60)?
#    Print their names and grades.
#
# 3. Find all **scholarship students from Manchester** with a Grade above 80.
#    Display Name, Grade, and Scholarship.

# %%
# Task 6 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# %% [markdown]
# ---
#
# ### Task 7: Add New Columns
#
# Add the following columns to the DataFrame:
#
# 1. **`Result`** — `'Pass'` if Grade >= 60, `'Fail'` otherwise.
#    Use `.apply()` with a `lambda` function.
#
# 2. **`Combined_Score`** — calculated as:
#    `Grade × 0.7 + Attendance × 0.3`
#    Round to 1 decimal place.
#
# 3. Display Name, Grade, Attendance, Result, Combined_Score for the **first 10 rows**.
#
# 4. Print how many students **Passed** and how many **Failed**.
#
# **Hint:** `df['Result'].value_counts()`

# %%
# Task 7 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# %% [markdown]
# ---
#
# ### Task 8: Course Statistics with Groupby
#
# Group the data by **Course** and calculate:
#
# - `Count` — number of students
# - `Avg_Grade` — average grade (rounded to 1 decimal)
# - `Max_Grade` — highest grade
# - `Avg_Attendance` — average attendance (rounded to 1 decimal)
#
# Use `groupby().agg()` with named aggregations.
#
# Sort the result by **Avg_Grade** from highest to lowest.
#
# **Expected output (approximate):**
# ```
#                   Count  Avg_Grade  Max_Grade  Avg_Attendance
# Course
# Computer Science      8       78.1         95            83.4
# Mathematics           6       82.2         91            86.3
# ...
# ```

# %%
# Task 8 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# %% [markdown]
# ---
#
# ### Task 9: Handling Missing Data
#
# Load **`week07_data/students_missing.csv`** (this file has some missing values).
#
# 1. Print how many missing values are in **each column**.
#
# 2. Display only the rows that have **at least one missing value**.
#
# 3. Fix the missing values:
#    - Fill missing **Grade** with the **column average** (round to 1 decimal).
#    - Fill missing **Scholarship** with `'Unknown'`.
#    - Fill missing **Course** with `'Unknown'`.
#    - Drop any rows where **Attendance** is missing.
#    - Drop any rows where **Age** is missing.
#
# 4. Check that no missing values remain (use `isnull().sum()`).
#
# 5. Save the cleaned DataFrame to `week07_data/students_clean.csv` (no index).
#
# **Hint:** Use `fillna()` for steps in part 3, and `dropna(subset=[...])` for dropping.

# %%
# Task 9 — your code here
import pandas as pd
df_missing = pd.read_csv('week07_data/students_missing.csv')

# %% [markdown]
# ---
#
# ### Task 10: City vs Scholarship Analysis
#
# Using the clean `students.csv`:
#
# 1. Group by **City** and count how many students are in each city.
#
# 2. Group by **City** and calculate the **average Grade** per city.
#    Sort from highest to lowest average.
#
# 3. Group by **Scholarship** and calculate the **average Grade**.
#    Does having a scholarship relate to higher grades?
#
# 4. Group by **City and Scholarship** together and count students.
#    Which city has the most scholarship students?
#
# **Hint:** For grouping by two columns: `df.groupby(['City', 'Scholarship'])`

# %%
# Task 10 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# %% [markdown]
# ---
#
# # Excellent
#
# > These tasks challenge you to **combine everything** — multi-step analysis, custom categorisation, and producing a real summary report. There is no single correct approach; aim for clear, readable code.

# %% [markdown]
# ---
#
# ### Task 11: Grade Bands
#
# Add a column called `Grade_Band` to the DataFrame using these rules:
#
# | Grade | Band |
# |-------|------|
# | 90 – 100 | `'A'` |
# | 80 – 89 | `'B'` |
# | 70 – 79 | `'C'` |
# | 60 – 69 | `'D'` |
# | below 60 | `'F'` |
#
# **Steps:**
#
# 1. Use a function with `apply()` or `pd.cut()` to create the `Grade_Band` column.
# 2. Display Name, Grade, and Grade_Band for all students.
# 3. Print a **count** of students per Grade Band (use `value_counts()`).
# 4. Which **course** has the most students with a Band A or B grade?
#
# **Hint for `pd.cut()`:**
# ```python
# bins   = [0, 59, 69, 79, 89, 100]
# labels = ['F', 'D', 'C', 'B', 'A']
# df['Grade_Band'] = pd.cut(df['Grade'], bins=bins, labels=labels)
# ```

# %%
# Task 11 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# %% [markdown]
# ---
#
# ### Task 12: City Performance Report
#
# Produce a **city-level performance summary** DataFrame with these columns:
#
# | Column | What to calculate |
# |--------|------------------|
# | `Students` | Count of students per city |
# | `Avg_Grade` | Average grade per city (1 dp) |
# | `Avg_Attendance` | Average attendance per city (1 dp) |
# | `Pass_Rate` | Percentage of students with Grade ≥ 60 (1 dp) |
# | `Performance` | `'Above Average'` if Avg_Grade > overall mean, else `'Below Average'` |
#
# **Steps:**
# 1. Calculate the overall average grade first (`df['Grade'].mean()`).
# 2. Build the summary using `groupby('City').agg()`.
# 3. Add the `Pass_Rate` column manually (calculate pass rate within each city group).
# 4. Add the `Performance` column comparing each city's avg grade to the overall mean.
# 5. Save the final summary to `week07_data/city_report.csv` (no index).
# 6. Print the table sorted by `Avg_Grade` (highest first).
#
# **Hint for Pass_Rate:**
# ```python
# # One way: calculate per city using transform or a lambda
# city_pass = df.groupby('City').apply(lambda g: (g['Grade'] >= 60).sum() / len(g) * 100)
# ```

# %%
# Task 12 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# %% [markdown]
# ---
#
# ### Task 13: Scholarship Deep Dive
#
# Investigate whether scholarships are awarded to the right students.
#
# **Answer each question with a `print()` statement and the calculation:**
#
# 1. What **percentage** of all students have a scholarship?
#
# 2. What is the **average Grade** for scholarship students vs non-scholarship students?
#    Is there a meaningful difference?
#
# 3. For each **Course**, calculate:
#    - Total students
#    - Students with scholarship
#    - Scholarship **rate** (as %)
#
#    Display as a table, sorted by scholarship rate (highest first).
#
# 4. Are scholarship students **more likely to attend** classes?
#    Compare average `Attendance` for scholarship vs non-scholarship.
#
# 5. Write a **short summary** (as a comment in the code cell) of your findings in 3-4 sentences.

# %%
# Task 13 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# 1. Scholarship percentage


# 2. Average grade: scholarship vs non-scholarship


# 3. Scholarship rate per course


# 4. Attendance comparison


# 5. Summary findings:
# ...

# %% [markdown]
# ---
#
# ### Task 14: Full EDA Report
#
# Using only Pandas, produce a **complete exploratory data analysis** of the students dataset.
#
# Answer **all** of the following questions:
#
# 1. Which **course is the most popular** (most students)?
# 2. Who are the **top 3 students** overall by Grade?
# 3. What is the **average attendance** for students who Pass vs Fail?
#    (Define Pass as Grade ≥ 60)
# 4. Is there a **correlation between Attendance and Grade**?
#    Use `.corr()` on those two columns and interpret the result in a comment.
# 5. Build and **export a course summary** to `week07_data/eda_report.csv` containing one row per course:
#
# | Column | Description |
# |--------|-------------|
# | `Course` | Course name |
# | `Student_Count` | Total students |
# | `Avg_Grade` | Average grade |
# | `Avg_Attendance` | Average attendance |
# | `Pass_Rate_Pct` | % of students with Grade ≥ 60 |
# | `Scholarship_Pct` | % of students with a scholarship |
#
# Print the final report table.
#
# ---
#
# **Hint — correlation interpretation:**
# ```
# Close to  1.0 → strong positive relationship
# Close to  0.0 → no relationship
# Close to -1.0 → strong negative relationship
# ```

# %%
# Task 14 — your code here
import pandas as pd
df = pd.read_csv('week07_data/students.csv')

# 1. Most popular course


# 2. Top 3 students


# 3. Average attendance: Pass vs Fail


# 4. Correlation between Attendance and Grade
# Interpretation: ...


# 5. Build and export the EDA report
